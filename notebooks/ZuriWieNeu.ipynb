# %% [markdown]
# # SDS210: ZüriWieNeu – Programmimng Project
# *This project focuses on analyzing reported urban issues in the city of Zurich.*

# %% [markdown]
# ## 1. Setup and Configuration
# * Import libraries (Pandas, GeoPandas)
# * Path definitions
# * Autoreload for helper scripts

# %%
import sys
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(".."))

print("Environment ready: Libraries loaded and paths set.")
# Out:
# Environment ready: Libraries loaded and paths set.

# %%
df = pd.read_csv('../data/raw/Reports/data/stzh.zwn_meldungen_p.csv', delimiter=',')
df.info()
print(df.columns.tolist())

gdf = gpd.read_file('../data/raw/Quartiere_ZH/data/stzh.adm_statistische_quartiere_b_p.json')
gdf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72933 entries, 0 to 72932
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   objectid              72933 non-null  int64
#  1   service_request_id    72933 non-null  int64
#  2   requested_datetime    72933 non-null  object
#  3   agency_sent_datetime  72109 non-null  object
#  4   updated_datetime      72933 non-null  object
#  5   e                     72933 non-null  int64
#  6   n                     72933 non-null  int64
#  7   service_code          72933 non-null  object
#  8   service_name          72933 non-null  object
#  9   status                72933 non-null  object
#  10  userid                72933 non-null  int64
#  11  title                 72931 non-null  object
#  12  detail                72931 non-null  object
#  13  media_url             50199 non-null  object
#  14  interface_used        72933 non-null  object
# ...

# %% [markdown]
# ## 2. Data Loading & Cleaning
# * Loading raw CSV (Reports) and GeoJSON (Neighbourhood Boundaries)
# * Standardizing CRS
# * Initial cleaning (remove unnecessary columns)

# %% [markdown]
# ## 3. Data Structuring (generate Master-File)
# * Spatial Join: Connect points to neighborhoods -> add to a new field **_Quartier_**
# * Calculate fields (Frustration level, Solving duration)

# %% [markdown]
# ## 4. Analysis: Answer specific Questions

# %% [markdown]
# ### 4.1 Q1: Report Density per Neighborhood

# %% [markdown]
# ### 4.2 Q2: Most Common Problem Categories

# %% [markdown]
# ### 4.3 Q3: Spatial Clustering of Frustrated Reports

# %% [markdown]
# ### 4.4 Q4: Solving-duration for _low_ vs. _high_ frustration levels

# %% [markdown]
# ## 5. Summary of Findings & Visualizations
